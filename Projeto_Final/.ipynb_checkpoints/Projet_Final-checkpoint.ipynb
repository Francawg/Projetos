# %% [markdown]
# ![ironhack.jpg](attachment:ironhack.jpg)

# %% [markdown]
# # Projeto final do curso de Data Analytics PT-JUL-2020, Ironhack São Paulo

# %% [markdown]
# ## Tema abordado: Técnicas de Machine Learning para Análise de Texto

# %% [markdown]
# **IRONHACKERS: GIULIANA VICENTE E WAGNER FRANÇA**

# %% [markdown]
# O presente projeto tem por objetivo analisar os textos produzidos por onze figuras políticas através da extração de dados de suas contas do Twitter. Para sua realização foi aplicado NLTK e SKLEARN com objetivo de treinar modelos de Regressão Logística que identificassem à qual figura política pertencem ou podem pertencer determinadas frases.

# %%
import nltk 
from nltk.stem import RSLPStemmer
import re
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression as lr
from sklearn.model_selection import train_test_split

# %% [markdown]
# #  Importando csv

# %% [markdown]
# **Figuras Políticas escolhidas:  Dilma Rousseff, Manuela d'Ávila, Marina Silva, Damares Alves, Bruno Covas, Guilherme Boulos, Jair Bolsonaro, Lula, Celso Russomanno, João Dória e Marcelo Crivella.**

# %%
tweet_covas = pd.read_csv ('C:/Users/User/explorar/covas-2020.csv')
tweet_boulos = pd.read_csv ('C:/Users/User/explorar/boulos-2020.csv').sample(2100)
tweet_russomanno = pd.read_csv ('C:/Users/User/explorar/celsorussomanno-2020.csv')
tweet_doria = pd.read_csv ('C:/Users/User/explorar/doria-2020.csv').sample(2100)
tweet_bolsonaro = pd.read_csv ('C:/Users/User/explorar/jairbolsonaro-2020.csv').sample(2100)
tweet_crivella = pd.read_csv ('C:/Users/User/explorar/crivela-2020.csv')
tweet_lula = pd.read_csv ('C:/Users/User/explorar/lula-2020.csv').sample(2100)
tweet_damares = pd.read_csv ('C:/Users/User/explorar/damares-2020.csv').sample(2100)
tweet_dilma = pd.read_csv ('C:/Users/User/explorar/dilmabr-2020.csv')
tweet_manuela = pd.read_csv ('C:/Users/User/explorar/ManuelaDavila-2020.csv').sample(2100)
tweet_marina = pd.read_csv ('C:/Users/User/explorar/MarinaSilva-2020.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-286d6a79caa0> in <module>
# ----> 1 tweet_covas = pd.read_csv ('C:/Users/User/Aulas_ironhack/Projeto_Final/Tweets para explorar/covas-2020.csv')
#       2 tweet_boulos = pd.read_csv ('C:/Users/User/Aulas_ironhack/Projeto_Final/Tweets para explorar/boulos-2020.csv').sample(2100)
#       3 tweet_russomanno = pd.read_csv ('C:/Users/User/Aulas_ironhack/Projeto_Final/Tweets para explorar/celsorussomanno-2020.csv')
#       4 tweet_doria = pd.read_csv ('C:/Users/User/Aulas_ironhack/Projeto_Final/Tweets para explorar/doria-2020.csv').sample(2100)
#       5 tweet_bolsonaro = pd.read_csv ('C:/Users/User/Aulas_ironhack/Projeto_Final/Tweets para explorar/jairbolsonaro-2020.csv').sample(2100)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/User/Aulas_ironhack/Projeto_Final/Tweets para explorar/covas-2020.csv'

# %%
covas = tweet_covas [["tweet" , "name"]]
boulos = tweet_boulos [["tweet" , "name"]]
russomanno = tweet_russomanno [["tweet" , "name"]]
doria = tweet_doria [["tweet" , "name"]]
bolsonaro = tweet_bolsonaro [["tweet" , "name"]]
crivella = tweet_crivella [["tweet" , "name"]]
lula = tweet_lula [["tweet" , "name"]]
damares = tweet_damares [["tweet" , "name"]]
dilma = tweet_dilma [["tweet" , "name"]]
manuela = tweet_manuela [["tweet" , "name"]]
marina = tweet_marina [["tweet" , "name"]]

# %% [markdown]
# ## Base de dados para treino e teste

# %%
tweets_treino = pd.concat([covas, boulos, russomanno, doria, bolsonaro, crivella, lula, dilma, damares, manuela, marina],ignore_index = True)
tweets_teste = pd.concat([covas.sample(100), boulos.sample(100), russomanno.sample(100), doria.sample(100), bolsonaro.sample(100), crivella.sample(100), lula.sample(100), dilma.sample(100), damares.sample(100), manuela.sample(100), marina.sample(100)],ignore_index = True)

# %% [markdown]
# ## Acrescentando a coluna Stemmer para testar a veracidade das stop words

# %%
stop_words = nltk.corpus.stopwords.words('portuguese')

# %%
def steming(df):
    

    for x in range(len(df['tweet'])):
            phrase = []
            tt = re.sub('[^\w\s]|\d','',df.iloc[x][0]).lower().split()
            for y in tt:
                if y not in stop_words:
                    phrase.append(RSLPStemmer().stem(y))
            joinha = ' '.join(map(str, phrase))
            df['tweet'].iloc[x] = joinha
            
    return df

# %% [markdown]
# ## Aplicando Stemmer no treino

# %%
steming(tweets_treino)
# Out:
#                                                    tweet          name
# 0                                     igor_k dia sáb top   Bruno Covas
# 1      obrig paul milhã vot ench esperanç hor transfo...   Bruno Covas
# 2       cole brun cov todosporsaopaul httpstcosldrgajzjn   Bruno Covas
# 3                                    vot todosporsaopaul   Bruno Covas
# 4      dur tod campanh preocup verdad palavr bonit pr...   Bruno Covas
# ...                                                  ...           ...
# 15894  irrespons negacion climá agrav aind situ tom m...  Marina Silva
# 15895  neglig primeiroministr australi scott morrison...  Marina Silva
# 15896  apavor ver terr incêndi florest austrál mat pe...  Marina Silva
# 15897  estratég trump ataqu busc reaviv nacion conser...  Marina Silva
# 15898  ataqu govern norteameric bagd mat gener irani ...  Marina Silva
#
# [15899 rows x 2 columns]

# %%
def digite():    
    frase = input('Digite uma frase: ')
    z = pd.DataFrame([frase], columns=['tweet'])
    steming(z)
    w = cv.transform (z['tweet']).todense()
    g = pd.DataFrame(w,columns=cv.get_feature_names())
    #results = pd.DataFrame(model.predict_proba(teste1),columns = model.classes_)
    wg = pd.DataFrame(model.predict_proba(g),columns = model.classes_).T
    return wg.reset_index().rename(columns={0: "Probabilidade", "index": "Candidato"})

    #return results[model.predict(teste1)[0]]

# %% [markdown]
# ## Aplicando a vetorização dos dados de texto e transformando-os em uma matriz de frequência

# %%
cv = CountVectorizer()
cv.fit(tweets_treino['tweet'])
# Out:
# CountVectorizer()

# %%
matrix = cv.transform (tweets_treino['tweet']).todense()

# %%
cv.get_feature_names()
# Out:
# ['__ucho',
#  '_anapastor_',
#  '_brunaf',
#  '_clacs',
#  '_cojub',
#  '_heloisa_helen',
#  '_lucasfigueired',
#  '_ludaltr',
#  '_nossieg',
#  '_ofic',
#  '_otauf',
#  '_pablitoagui',
#  '_pinh',
#  '_sapata',
#  '_uivan',
#  '_zevagn',
#  'a_estupid',
#  'aa',
#  'aaaalô',
#  'aaaeguarujásp',
#  'aba',
#  'abaf',
#  'abaix',
#  'abaixoacens',
#  'abaixoassin',
#  'abal',
#  'aban',
#  'abandon',
#  'abastec',
#  'abastecimentosegurospgovbr',
#  'abasteç',
#  'abat',
#  'abc',
#  'abdi_digit',
#  'abdic',
#  'abduch',
#  'abduç',
#  'abelh',
#  'abenf',
#  'abenço',
#  'abençõ',
#  'aberr',
#  'abert',
#  'abeshinz',
#  'abin',
#  'abism',
#  'abjet',
#  'abneg',
#  'abnerdangel',
#  'abol',
#  'abomin',
#  'abon',
#  'abord',
#  'abort',
#  'about',
#  'abp',
#  'abr',
#  'abrac',
#  'abraceomaraj',
#  'abraceomarajó',
#  'abraceori',
#  'abracosolidari',
#  'abracovirt',
#  'abrah',
#  'abrahamweint',
#  'abrahim',
#  'abrang',
#  'abraz',
#  'abraç',
#  'abraçál',
#  'abres',
#  'abrevi',
#  'abrig',
#  'abril',
#  'abrilazul',
#  'abrilhant',
#  'abrilindígen',
#  'abrir',
#  'abrupt',
#  'absolut',
#  'absolv',
#  'absorv',
#  'abstenç',
#  'abstin',
#  'abstrat',
#  'absurd',
#  'abu',
#  'abuel',
#  'abuelasdifusion',
#  'abunã',
#  'abus',
#  'abusonãoébrinc',
#  'abutr',
#  'ac',
#  'acab',
#  'acaboubolsonar',
#  'acaboul',
#  'academ',
#  'acadepol',
#  'acadêm',
#  'acajutib',
#  'acalent',
#  'acalm',
#  'acamp',
#  'acanh',
#  'acaodacidadan',
#  'acare',
#  'acarlaosant',
#  'acarolamar',
#  'acarret',
#  'acas',
#  'acat',
#  'acc',
#  'acceitec',
#  'accioly',
#  'aceit',
#  'aceler',
#  'acen',
#  'acend',
#  'acepç',
#  'acert',
#  'acertad',
#  'acerv',
#  'aces',
#  'acess',
#  'acessibil',
#  'acessóri',
#  'ach',
#  'acharamrozanabarr',
#  'achat',
#  'achermoul',
#  'achincalh',
#  'aci',
#  'acid',
#  'acident',
#  'acim',
#  'acion',
#  'acm',
#  'acobert',
#  'acolh',
#  'acolhaav',
#  'acolhedorassetembroamarel',
#  'acolhinent',
#  'acomet',
#  'acomoanh',
#  'acomod',
#  'acompanh',
#  'aconselh',
#  'acontec',
#  'aconteç',
#  'acopi',
#  'acopl',
#  'acord',
#  'acostum',
#  'acr',
#  'acre',
#  'acredit',
#  'acreditasãopaul',
#  'acrescent',
#  'acrescentes',
#  'acrislil',
#  'acrpol',
#  'acrésc',
#  'acríl',
#  'act',
#  'activat',
#  'acu',
#  'acumplic',
#  'acumul',
#  'acus',
#  'acusando',
#  'acusál',
#  'acéfal',
#  'acórd',
#  'acõ',
#  'acúmul',
#  'ad',
#  'ada',
#  'adacolau',
#  'adadlel',
#  'adalt',
#  'adapt',
#  'adct',
#  'adel',
#  'adelisell',
#  'adelsonantoni',
#  'adem',
#  'ademirduarteb',
#  'adept',
#  'adequ',
#  'adequad',
#  'ader',
#  'ades',
#  'adesiv',
#  'adeu',
#  'adgm',
#  'adi',
#  'adiaen',
#  'adiant',
#  'adic',
#  'adicion',
#  'adilson',
#  'adilsonaraj',
#  'adilsonctb',
#  'adiv',
#  'adivinh',
#  'adjunt',
#  'adm',
#  'administr',
#  'admir',
#  'admiss',
#  'admissibil',
#  'admit',
#  'adnet',
#  'adoaçãorespons',
#  'adoec',
#  'adolesc',
#  'adolescentesdev',
#  'adolf',
#  'ador',
#  'adormec',
#  'adot',
#  'adotál',
#  'adoç',
#  'adpf',
#  'adqu',
#  'adquir',
#  'adri',
#  'adriana_accors',
#  'adrianopiresc',
#  'adrianotomason',
#  'adsclet',
#  'adsens',
#  'adu',
#  'adult',
#  'adulter',
#  'advanc',
#  'advent',
#  'advers',
#  'adversár',
#  'advert',
#  'advocac',
#  'advocaciager',
#  'advog',
#  'adági',
#  'adã',
#  'aeromó',
#  'aeron',
#  'aeronav',
#  'aeronáu',
#  'aeronáuticaeea',
#  'aeroport',
#  'aeroportu',
#  'aeroportuár',
#  'aerovi',
#  'aeródr',
#  'af',
#  'afag',
#  'afast',
#  'afeit',
#  'afenicolin',
#  'aferr',
#  'afet',
#  'afili',
#  'afim',
#  'afin',
#  'afinal',
#  'afirm',
#  'afirmars',
#  'afix',
#  'aflig',
#  'aflit',
#  'aflor',
#  'afog',
#  'afogadilh',
#  'afons',
#  'afonsob',
#  'afor',
#  'afric',
#  'african',
#  'afrobrasil',
#  'afront',
#  'afroux',
#  'aft',
#  'afu',
#  'afugent',
#  'afund',
#  'afã',
#  'ag',
#  'agafarm',
#  'against',
#  'agarr',
#  'agasalh',
#  'age',
#  'agenciabrasil',
#  'agenciafapesp',
#  'agenciapubl',
#  'agend',
#  'agent',
#  'aggression',
#  'agid',
#  'agil',
#  'agiliz',
#  'agim',
#  'agind',
#  'agir',
#  'agirm',
#  'agiss',
#  'agit',
#  'agiu',
#  'aglomer',
#  'agmaestr',
#  'ago',
#  'agoeaémanuel',
#  'agoniz',
#  'agor',
#  'agorac',
#  'agoraemanuel',
#  'agoranoticiasbr',
#  'agoraé',
#  'agoraéanossav',
#  'agoraéavezdasmulh',
#  'agoraéboul',
#  'agoraémanuel',
#  'agoraémanuerossett',
#  'agoraénossav',
#  'agoraépravenc',
#  'agost',
#  'agr',
#  'agraci',
#  'agrad',
#  'agradec',
#  'agradeç',
#  'agrand',
#  'agrav',
#  'agred',
#  'agreg',
#  'agres',
#  'agress',
#  'agressoresband',
#  'agrest',
#  'agresteest',
#  'agricul',
#  'agricult',
#  'agrid',
#  'agroambient',
#  'agroecolog',
#  'agroecológ',
#  'agroindústr',
#  'agronegóci',
#  'agropecu',
#  'agropecuár',
#  'agrosp',
#  'agrotóx',
#  'agrár',
#  'agrícol',
#  'agu',
#  'aguanaoemercad',
#  'aguard',
#  'agud',
#  'aguent',
#  'aguerr',
#  'agui',
#  'aguilh',
#  'agustin',
#  'agustín',
#  'agênc',
#  'agênciabarc',
#  'agênciasbarc',
#  'ah',
#  'ahmed',
#  'ahorapod',
#  'ahpronto__',
#  'ai',
#  'aia',
#  'ailton',
#  'ailtonbenedit',
#  'aind',
#  'air',
#  'airlin',
#  'airport',
#  'aja',
#  'ajorgemed',
#  'ajud',
#  'ajudál',
#  'ajuiz',
#  'ajust',
#  'ajvalc',
#  'akopian',
#  'akshardh',
#  'akwrolin',
#  'al',
#  'ala',
#  'alag',
#  'alago',
#  'alambar',
#  'alambr',
#  'alan',
#  'alanapassosrj',
#  'alanf_barr',
#  'alanlopesri',
#  'alarcon',
#  'alarg',
#  'alarm',
#  'alastr',
#  'alavanc',
#  'alberg',
#  'albert',
#  'albertocumpl',
#  'albin',
#  'albuquerquedavy',
#  'alc',
#  'alcald',
#  'alcanc',
#  'alcanç',
#  'alceu_valenc',
#  'alcid',
#  'alckmin',
#  'alcolumbr',
#  'alcoól',
#  'alcânt',
#  'alcântaram',
#  'ald',
#  'alde',
#  'ale_botelh',
#  'aleatóri',
#  'aleestefan',
#  'aleg',
#  'alegr',
#  'alegrál',
#  'alegrí',
#  'aleit',
#  'alejandr',
#  'alejandrodott',
#  'aleksandr',
#  'alem',
#  'alemanh',
#  'alenc',
#  'alencastr',
#  'alent',
#  'alerj',
#  'alert',
#  'alesp',
#  'alessan',
#  'alessandr',
#  'alessandroloi',
#  'alessandromolon',
#  'alessi',
#  'alevidalx',
#  'alex',
#  'alexand',
#  'alexandr',
#  'alexandregarc',
#  'alexandreziben',
#  'alexcat',
#  'alexoliveirr',
#  'alexyasalv',
#  'alfabe',
#  'alfabet',
#  'alfandeg',
#  'alfarfall',
#  'alferd',
#  'alfred',
#  'alfredosirkil',
#  'alg',
#  'algoritm',
#  'algoz',
#  'algum',
#  'alguém',
#  'alh',
#  'alhe',
#  'alhei',
#  'alhulaiab',
#  'ali',
#  'alianç',
#  'aliançapelobrasil',
#  'alic',
#  'alice_portug',
#  'alicerc',
#  'alien',
#  'alij',
#  'aliment',
#  'alimentacaosauda',
#  'alimentíc',
#  'alimentíci',
#  'alimond',
#  'alin',
#  'alinemidlej',
#  'alinh',
#  'alivi',
#  'aliás',
#  'alkmin',
#  'alkorap',
#  'all',
#  'allan',
#  'allanldsant',
#  'allantercalivr',
#  'allef_borg',
#  'alm',
#  'alme',
#  'almir',
#  'almoc',
#  'almoç',
#  'almsandr',
#  'aloc',
#  'aloch',
#  'aloj',
#  'along',
#  'alopr',
#  'alp',
#  'alphonsovm',
#  'alqu',
#  'alrasheed',
#  'als',
#  'alsuwaid',
#  'alt',
#  'altam',
#  'alter',
#  'altern',
#  'altin',
#  'altiv',
#  'altman',
#  'altruísm',
#  'altur',
#  'alug',
#  'aluguel',
#  'alumíni',
#  'alun',
#  'alunom',
#  'alus',
#  'alv',
#  'alvar',
#  'alvim',
#  'alvin',
#  'alvinegr',
#  'alvor',
#  'alwaslsc',
#  'alzheim',
#  'alç',
#  'além',
#  'alê',
#  'alíquot',
#  'alívi',
#  'alô',
#  'am',
#  'ama',
#  'amad',
#  'amadurec',
#  'amaldiço',
#  'amament',
#  'aman',
#  'amanc',
#  'amand',
#  'amandkl',
#  'amandystein',
#  'amanhec',
#  'amanhã',
#  'amanim',
#  'amanpour',
#  'amap',
#  'amapa',
#  'amapapedesocorr',
#  'amapárestabelec',
#  'amar',
#  'amarantern',
#  'amarel',
#  'amarg',
#  'amarrando',
#  'amaur',
#  'amazing',
#  'amazon',
#  'amazonasp',
#  'amazoniaazulbr',
#  'amazôn',
#  'amb',
#  'ambas',
#  'ambi',
#  'ambici',
#  'ambicion',
#  'ambient',
#  'ambos',
#  'ambul',
#  'ambulanteleg',
#  'ambulatóri',
#  'ambulânc',
#  'ambígu',
#  'ame',
#  'ameac',
#  'amealh',
#  'ameaç',
#  'amei',
#  'amen',
#  'amendoncaagu',
#  'amendoncamjsp',
#  'ameniz',
#  'amer',
#  'americ',
#  'american',
#  'americanasbrasil',
#  'amig',
#  'amit',
#  'amizad',
#  'amo',
#  'amon',
#  'among',
#  'amongboul',
#  'amongboulu',
#  'amooo',
#  'amor',
#  'amorim',
#  'amorsinhopret',
#  'amosp',
#  'amostr',
#  'amotin',
#  'amou',
#  'amp',
#  'ampar',
#  'ampl',
#  'ampli',
#  'amplific',
#  'amplitud',
#  'amrig',
#  'amurtamurtel',
#  'amál',
#  'amél',
#  'amém',
#  'amér',
#  'an',
#  'ana',
#  'anacmielk',
#  'anadut',
#  'anal',
#  'analfabet',
#  'analgés',
#  'analis',
#  'analog',
#  'analy',
#  'anamel',
#  'anamesm',
#  'anan',
#  'ananindeu',
#  'anapaulavol',
#  'anapu',
#  'anarcofin',
#  'anavitór',
#  'anc',
#  'ancestr',
#  'anchiet',
#  'anchieta',
#  'ancin',
#  'ancor',
#  'and',
#  'andanew',
#  'andaraí',
#  'anderson',
#  'andersondaleci',
#  'andersonpsol',
#  'andes_pedr',
#  'andrad',
#  'andradin',
#  'andrdin',
#  'andre',
#  'andreabocell',
#  'andreaf',
#  'andrefernm',
#  'andrefran',
#  'andreiadejesuu',
#  'andrejanonesadv',
#  'andrepetr',
#  'andress',
#  'android',
#  'andré',
#  'aneel',
#  'aneel_govbr',
#  'anel',
#  'anencefal',
#  'anestes',
#  'anestesi',
#  'anex',
#  'angel',
#  'angela_gandr',
#  'angelpelobrasil',
#  'angol',
#  'angr',
#  'angusti',
#  'angél',
#  'angúst',
#  'anhagabaú',
#  'anhangabaú',
#  'anhemb',
#  'anholet',
#  'anielle_franc',
#  'aniellefranc',
#  'anil',
#  'anim',
#  'animal',
#  'animaldecret',
#  'aninh',
#  'aniquil',
#  'anist',
#  'anisti',
#  'anitt',
#  'aniversári',
#  'anj',
#  'anjunhun',
#  'anm',
#  'ann',
#  'anna_cavazzin',
#  'anne_hidalg',
#  'anniversary',
#  'anny_mont',
#  'ano',
#  'anonim',
#  'anonimat',
#  'anonov',
#  'anonym',
#  'anoparticip',
#  'anormal',
#  'anoscorinth',
#  'anosmuit',
#  'anossemdorothy',
#  'anot',
#  'anoth',
#  'anse',
#  'ansei',
#  'ansi',
#  'ant',
#  'antagon',
#  'antagôn',
#  'anteced',
#  'antecip',
#  'anter',
#  'anteri',
#  'anterogrec',
#  'antesal',
#  'anthony',
#  'antiabort',
#  'antiambient',
#  'antibrasil',
#  'anticientíf',
#  'anticrim',
#  'antidemocrá',
#  'antidrog',
#  'antif',
#  'antifasc',
#  'antifaspelademocrac',
#  'antifraud',
#  'antig',
#  'antihuman',
#  'antiindígen',
#  'antimanicom',
#  'antiministr',
#  'antipet',
#  'antipolí',
#  'antirac',
#  'antirepublic',
#  'antirrac',
#  'antirrasc',
#  'antirrepublic',
#  'antirretrovir',
#  'antisemit',
#  'antissemit',
#  'antissequestr',
#  'antivacin',
#  'antivir',
#  'antié',
#  'anton',
#  'antoni',
#  'antoniet',
#  'antonin',
#  'antoniofsnetosp',
#  'antoniograss',
#  'antorac',
#  'antropólog',
#  'antun',
#  'antárt',
#  'antídot',
#  'antígu',
#  'antôni',
#  'anual',
#  'anul',
#  'anulastf',
#  'anunc',
#  'anunci',
#  'anvis',
#  'anvisa_ofic',
#  'anális',
#  'análog',
#  'anápolisg',
#  'anísi',
#  'anôn',
#  'anúnci',
#  'aond',
#  'aoviv',
#  'ap',
#  'apa',
#  'apadrinh',
#  'apag',
#  'apaixon',
#  'apanh',
#  'aparat',
#  'aparec',
#  'aparelh',
#  'aparent',
#  'apareç',
#  'apart',
#  'apartidár',
#  'apatif',
#  'apatifamn',
#  'apavor',
#  'apcesaraugust',
#  'apeg',
#  'apegas',
#  'apel',
#  'apen',
#  'apeoesp',
#  'apequen',
#  'aperfeiço',
#  'apert',
#  'apertaev',
#  'apes',
#  'apetit',
#  'apezequiel',
#  'api',
#  'apib',
#  'apibofic',
#  'apicul',
#  'apicult',
#  'apit',
#  'aplaud',
#  'aplaus',
#  'aplic',
#  'apo',
#  'apocalip',
#  'apocalips',
#  'apoi',
#  'apoiobrequedosapp',
#  'apoiál',
#  'apolog',
#  'apont',
#  'aport',
#  'aposent',
#  'aposentad',
#  'apost',
#  'apostól',
#  'apoteos',
#  'app',
#  'apreci',
#  'apreend',
#  'apreens',
#  'aprend',
#  'aprendiz',
#  'apres',
#  'apresent',
#  'apresentars',
#  'apress',
#  'apreç',
#  'aprim',
#  'aprimor',
#  'aprision',
#  'aprofund',
#  'apront',
#  'apropri',
#  'apropriad',
#  'aprov',
#  'aprovaaldirblancintegr',
#  'aprovadofundebpraval',
#  'aprovaemergenciacult',
#  'aprovafundeb',
#  'aprovafundebintegr',
#  'aprovafundebj',
#  'aprovasenadopl',
#  'aprove',
#  'aproveit',
#  'aproveitars',
#  'aprovál',
#  'aprox',
#  'aproxim',
#  'aproximad',
#  'apsen',
#  'apt',
#  'apur',
#  'apyterew',
#  'apó',
#  'apócrif',
#  'após',
#  'aqu',
#  'aquavi',
#  'aquaviár',
#  'aquaviáriocabot',
#  'aquec',
#  'aquecêl',
#  'aquis',
#  'aquá',
#  'aquí',
#  'aquífer',
#  'ar',
#  'ara',
#  'aracaju',
#  'aracajus',
#  'aracajú',
#  'aragua',
#  'aram',
#  'arand',
#  'arapong',
#  'arapu',
#  'arapuan',
#  'arar',
#  'araraqu',
#  'ararasazuil',
#  'ararib',
#  'aratub',
#  'araut',
#  'araçariguam',
#  'araçatub',
#  'araçuaí',
#  'araçuaímg',
#  'araúj',
#  'arbitr',
#  'arbitrariedad',
#  'arbitrár',
#  'arbor',
#  'arbítri',
#  'arc',
#  'arcanj',
#  'arcebisp',
#  'arcondicion',
#  'ard',
#  'ardern',
#  'ardil',
#  'ardu',
#  'are',
#  'arej',
#  'aren',
#  'argent',
#  'argentin',
#  'argument',
#  'arian',
#  'aricanduv',
#  'arid',
#  'ariovald',
#  'arit',
#  'aritmé',
#  'arm',
#  'armadilh',
#  'arman',
#  'armand',
#  'armazen',
#  'armazém',
#  'armên',
#  'armêni',
#  'arnald',
#  'arnaldo_antun',
#  'arnsflavi',
#  'arold',
#  'aroldeoliv',
#  'arom',
#  'arqmrf',
#  'arqu',
#  'arquibanc',
#  'arquipélag',
#  'arquitet',
#  'arquiv',
#  'arra',
#  'arraig',
#  'arranc',
#  'arranj',
#  'arras',
#  'arrast',
#  'arrecad',
#  'arrecadatór',
#  'arrefec',
#  'arregaç',
#  'arremat',
#  'arremet',
#  'arrend',
#  'arrep',
#  'arrepend',
#  'arrepi',
#  'arret',
#  'arrisc',
#  'arrisqu',
#  'arritm',
#  'arrog',
#  'arroi',
#  'arroj',
#  'arromb',
#  'arroub',
#  'arroz',
#  'arrud',
#  'arrum',
#  'arsen',
#  'art',
#  'artax',
#  'artedeensin',
#  'artes',
#  'artesan',
#  'artesi',
#  'artesp',
#  'arthur',
#  ...]

# %%
teste = pd.DataFrame(matrix,columns=cv.get_feature_names())

# %%
X = teste
y = tweets_treino['name']

# %% [markdown]
# ## Treinando Modelo de Regressão Logística

# %%
model = lr(solver='lbfgs', max_iter=1000)
model.fit(X,y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#testando modelo
model.predict(X)
# Out:
# array(['Bruno Covas', 'Bruno Covas', 'Bruno Covas', ..., 'Marina Silva',
#        'Marina Silva', 'Marina Silva'], dtype=object)

# %%
model.classes_
# Out:
# array(['Bruno Covas', 'Celso Russomanno', 'Damares Alves',
#        'Dilma Rousseff', 'Guilherme Boulos', 'Jair M. Bolsonaro',
#        'João Doria', 'Lula', 'Manuela', 'Marcelo Crivella',
#        'Marina Silva'], dtype=object)

# %%
digite()
# Out:
# Digite uma frase: Lula Livre
#             Candidato  Probabilidade
# 0         Bruno Covas       0.000918
# 1    Celso Russomanno       0.002909
# 2       Damares Alves       0.007586
# 3      Dilma Rousseff       0.034506
# 4    Guilherme Boulos       0.028395
# 5   Jair M. Bolsonaro       0.044223
# 6          João Doria       0.004700
# 7                Lula       0.807854
# 8             Manuela       0.057101
# 9    Marcelo Crivella       0.002688
# 10       Marina Silva       0.009120
